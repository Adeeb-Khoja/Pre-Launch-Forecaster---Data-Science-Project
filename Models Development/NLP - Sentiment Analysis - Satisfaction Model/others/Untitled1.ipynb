# %%
import os
import csv
import tweepy as tw
import pandas as pd
from twython import Twython
from twython import TwythonStreamer
import GetOldTweets3 as got

# %%
consumer_key="DSBPI5oyPQEiY3qgg2fecQuLR"
consumer_secret="cqKaon6dQdl66WW55HbuQal89A1cRuFuMY3EwhxgUJVu44Vpnu"
access_token="353386879-jA0Td42vAAz8tSRWZb8MozhAppx8KNEypHQEHp9G"
access_token_secret="LhFN9joYIFndaBmXKU7Ws3M1YkpwfeWPkuKEYqNtW97Qf"
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
new_search = 'google' + " -filter:retweets"
new_search
# Out:
# 'google -filter:retweets'

# %%
tweets = tw.Cursor(api.search, 
                           q=new_search,
                           lang="en",
                           since="2000-11-16",
                  until="2021-11-16").items(20)

users_locs = [[tweet.user.screen_name, tweet.user.location,tweet.created_at] for tweet in tweets]

# %%
twitter = Twython(consumer_key, consumer_secret,
                  access_token, access_token_secret)

# %%
twitter.search(q='dodge', result_type='popular')
# Out:
# {'statuses': [{'created_at': 'Tue Mar 09 14:00:47 +0000 2021',
#    'id': 1369287051288469504,
#    'id_str': '1369287051288469504',
#    'text': 'The bigger the ride, the bigger the thrill.\n#DodgeDurango #Hellcat https://t.co/kbztDPND6V',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'DodgeDurango', 'indices': [44, 57]},
#      {'text': 'Hellcat', 'indices': [58, 66]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1369287022754623493,
#       'id_str': '1369287022754623493',
#       'indices': [67, 90],
#       'media_url': 'http://pbs.twimg.com/media/EwCvStrXcAUhvPG.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/EwCvStrXcAUhvPG.jpg',
#       'url': 'https://t.co/kbztDPND6V',
#       'display_url': 'pic.twitter.com/kbztDPND6V',
#       'expanded_url': 'https://twitter.com/Dodge/status/1369287051288469504/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
# ...

# %%
class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            username = data['user']['screen_name']
            tweet = data['text']
            date =  data['created_at']
            print("@{}: {}: {}".format(username, tweet,date))

# %%
stream = MyStreamer(
    consumer_key,
    consumer_secret,
    access_token,
    access_token_secret
)
stream.statuses.filter(track='raspberry pi')
# Out:
# @YvesPDB: RT @RebeccaRambar: Russie : Les progrès de la «tourelle laser anti-moustique» sont interrompus en raison de l'hiver
# Le créateur prétend que…: Tue Mar 09 20:38:53 +0000 2021
# @RasPizero_BOT: 5時39分現在・室温 18.2℃・気圧 1022hPa・湿度 44.5％・ Raspberry Pi 温度 30.4℃: Tue Mar 09 20:39:04 +0000 2021
# @GeekeryService: Telling Jokes to Astronauts on the Space Station with a Raspberry Pi! https://t.co/AhXAbPUS4n: Tue Mar 09 20:39:55 +0000 2021
# @RasPizero_BOT: 5時40分現在・室温 18.1℃・気圧 1022hPa・湿度 44.8％・ Raspberry Pi 温度 30.9℃: Tue Mar 09 20:40:04 +0000 2021
# @HexabitzInc: RT @HexabitzInc: Adding a #real time clock to #raspberrypi ⏰ 🧩🙂🔋
# https://t.co/YBn4XniMTE
# https://t.co/cDe9nrFsO5
# #MonthOfMaking #100DaysOfC…: Tue Mar 09 20:40:34 +0000 2021
# @BigNerdLilNerd: RT @BigNerdLilNerd: Cheat sheet of Raspberry Pi commands https://t.co/c7kLmZs9fw: Tue Mar 09 20:41:00 +0000 2021
# @RasPizero_BOT: 5時41分現在・室温 18.1℃・気圧 1022hPa・湿度 44.6％・ Raspberry Pi 温度 31.5℃: Tue Mar 09 20:41:04 +0000 2021
# ...

# %%
import GetOldTweets3 as got

tweetCriteria = got.manager.TweetCriteria().setUsername("barackobama whitehouse")\
                                           .setMaxTweets(2)
tweet = got.manager.TweetManager.getTweets(tweetCriteria)[0]
print(tweet.text)
# Out:
# An error occured during an HTTP request: HTTP Error 404: Not Found
# Try to open in browser: https://twitter.com/search?q=%20from%3Abarackobama%20whitehouse&src=typd
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
GetOldTweets3 --username "barackobama" --since 2015-09-10 --until 2015-09-12 --maxtweets 10 --emoji unicode
# Out:
#   File "<ipython-input-52-c161b4804ea1>", line 1
#     GetOldTweets3 --username "barackobama" --since 2015-09-10 --until 2015-09-12 --maxtweets 10 --emoji unicode
#                                          ^
# SyntaxError: invalid syntax
