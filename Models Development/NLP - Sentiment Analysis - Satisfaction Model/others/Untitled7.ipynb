# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/abdul/Desktop/FYP/BMW_FET.csv')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#                                           Vehicle_Title  \
# 0     2014 BMW X1 SUV xDrive28i 4dr SUV AWD (2.0L 4c...
# 1     2014 BMW X1 SUV xDrive28i 4dr SUV AWD (2.0L 4c...
# 2     2014 BMW X1 SUV xDrive28i 4dr SUV AWD (2.0L 4c...
# 3     2014 BMW X1 SUV xDrive28i 4dr SUV AWD (2.0L 4c...
# 4     2014 BMW X1 SUV xDrive28i 4dr SUV AWD (2.0L 4c...
# ...                                                 ...
# 8055       2010 BMW M5 Sedan 4dr Sedan (5.0L 10cyl 7AM)
# 8056       2010 BMW M5 Sedan 4dr Sedan (5.0L 10cyl 7AM)
# 8057  2013 BMW M5 Sedan 4dr Sedan (4.4L 8cyl Turbo 7AM)
# 8058  2013 BMW M5 Sedan 4dr Sedan (4.4L 8cyl Turbo 7AM)
# 8059  2013 BMW M5 Sedan 4dr Sedan (4.4L 8cyl Turbo 7AM)
#
#                               Review_Title  \
# 0                                  Love it
# 1                     OK with Reservations
# 2                            Love this car
# 3            Worst Purchase I've ever made
# 4                                    car 1
# ...                                    ...
# 8055                         The best ever
# 8056  Great uncomfortable car for everyday
# 8057                        2013 M5 Loaded
# 8058                           M5 Get one.
# 8059                                 Happy
#
#                                                  Review  Ratings Model  \
# 0                      Beautiful car.  Love all aspects    5.000    X1
# 1      We picked this car as a CPO from a BMW dealer...    3.000    X1
# 2      Get ride of the run flats.   If you like to d...    5.000    X1
# 3      1.\tDealership was a joke to work with, lied ...    1.000    X1
# 4                         Handy as a pocket on a shirt.    5.000    X1
# ...                                                 ...      ...   ...
# 8055   I do have the pleasure to tell you guys, that...    4.875    M5
# 8056   This is my fifth BMW and third M car. First M...    4.125    M5
# 8057   So far so good. Had the car for about a week....    5.000    M5
# 8058                                                       5.000    M5
# 8059                                    Great large car    5.000    M5
#
#         Year             Engine Fuel Type  Engine HP  Engine Cylinders  \
# 0     2015.0  premium unleaded (required)      240.0               4.0
# 1     2015.0  premium unleaded (required)      240.0               4.0
# 2     2015.0  premium unleaded (required)      240.0               4.0
# 3     2015.0  premium unleaded (required)      240.0               4.0
# 4     2015.0  premium unleaded (required)      240.0               4.0
# ...      ...                          ...        ...               ...
# 8055  2014.0  premium unleaded (required)      552.0               8.0
# 8056  2014.0  premium unleaded (required)      552.0               8.0
# 8057  2014.0  premium unleaded (required)      552.0               8.0
# 8058  2014.0  premium unleaded (required)      552.0               8.0
# 8059  2014.0  premium unleaded (required)      552.0               8.0
#
#      Transmission Type     Driven_Wheels  Number of Doors  \
# 0            AUTOMATIC  rear wheel drive              4.0
# 1            AUTOMATIC  rear wheel drive              4.0
# 2            AUTOMATIC  rear wheel drive              4.0
# 3            AUTOMATIC  rear wheel drive              4.0
# 4            AUTOMATIC  rear wheel drive              4.0
# ...                ...               ...              ...
# 8055  AUTOMATED_MANUAL  rear wheel drive              4.0
# 8056  AUTOMATED_MANUAL  rear wheel drive              4.0
# 8057  AUTOMATED_MANUAL  rear wheel drive              4.0
# 8058  AUTOMATED_MANUAL  rear wheel drive              4.0
# 8059  AUTOMATED_MANUAL  rear wheel drive              4.0
#
#                             Market Category Vehicle Size  highway MPG  \
# 0              Crossover,Luxury,Performance      Midsize         34.0
# 1              Crossover,Luxury,Performance      Midsize         34.0
# 2              Crossover,Luxury,Performance      Midsize         34.0
# 3              Crossover,Luxury,Performance      Midsize         34.0
# 4              Crossover,Luxury,Performance      Midsize         34.0
# ...                                     ...          ...          ...
# 8055  Factory Tuner,Luxury,High-Performance        Large         20.0
# 8056  Factory Tuner,Luxury,High-Performance        Large         20.0
# 8057  Factory Tuner,Luxury,High-Performance        Large         20.0
# 8058  Factory Tuner,Luxury,High-Performance        Large         20.0
# 8059  Factory Tuner,Luxury,High-Performance        Large         20.0
#
#       city mpg  Popularity     MSRP Vehicle Style
# 0         23.0      3916.0  31200.0       4dr SUV
# 1         23.0      3916.0  31200.0       4dr SUV
# 2         23.0      3916.0  31200.0       4dr SUV
# 3         23.0      3916.0  31200.0       4dr SUV
# 4         23.0      3916.0  31200.0       4dr SUV
# ...        ...         ...      ...           ...
# 8055      14.0      3916.0  92900.0         Sedan
# 8056      14.0      3916.0  92900.0         Sedan
# 8057      14.0      3916.0  92900.0         Sedan
# 8058      14.0      3916.0  92900.0         Sedan
# 8059      14.0      3916.0  92900.0         Sedan
#
# [8060 rows x 19 columns]

# %%
#checking for missing data and output the number of records and their percentage
count = df.isnull().sum().sort_values(ascending = False)
percentage=((df.isnull().sum()/len(df)*100)).sort_values(ascending = False)
missing_data=pd.concat([count,percentage], axis=1 
,keys=["number of missing data","percentage of missing data"])
missing_data
# Out:
#                    number of missing data  percentage of missing data
# Transmission Type                      33                    0.409429
# Driven_Wheels                          33                    0.409429
# MSRP                                   33                    0.409429
# Popularity                             33                    0.409429
# city mpg                               33                    0.409429
# highway MPG                            33                    0.409429
# Vehicle Size                           33                    0.409429
# Market Category                        33                    0.409429
# Number of Doors                        33                    0.409429
# Vehicle Style                          33                    0.409429
# Engine Cylinders                       33                    0.409429
# Engine HP                              33                    0.409429
# Engine Fuel Type                       33                    0.409429
# Year                                   33                    0.409429
# Model                                  33                    0.409429
# Review_Title                            0                    0.000000
# Ratings                                 0                    0.000000
# Review                                  0                    0.000000
# Vehicle_Title                           0                    0.000000

# %%
print(df.loc[[1335]])
# Out:
#                                           Vehicle_Title Review_Title  \
# 1335  2018 BMW X2 SUV xDrive28i 4dr SUV AWD (2.0L 4c...    X2 beamer
#
#                                                  Review  Ratings Model  Year  \
# 1335   Nice looking car.  Pleasant to  drive.    Ver...      3.0   NaN   NaN
#
#      Engine Fuel Type  Engine HP  Engine Cylinders Transmission Type  \
# 1335              NaN        NaN               NaN               NaN
#
#      Driven_Wheels  Number of Doors Market Category Vehicle Size  highway MPG  \
# 1335           NaN              NaN             NaN          NaN          NaN
#
#       city mpg  Popularity  MSRP Vehicle Style
# 1335       NaN         NaN   NaN           NaN
